# %% [raw]
# ---
# title: "EDA"
# format:
#   html:
#     toc: true
#     embed-resources: true
#     theme: yeti
#     code-fold: true
# execute:
#   echo: true
# ---

# %% [markdown]
# # EDA
# ## Introduction
# ## Code

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
import math

# %%
# Data Loading
pd.set_option('display.max_columns', None)

df = pd.read_csv('../../data/rawdata/T_DB1B_MARKET_CLEAN.csv')   

# Data Overview
print("Data Loaded")
print(df.shape)
df.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9408\2164937600.py:4: DtypeWarning: Columns (6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/rawdata/T_DB1B_MARKET_COMBINED.csv')
# Data Loaded
# (32343186, 17)
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# 0              10135                1013506                  30135
# 1              10135                1013506                  30135
# 2              10135                1013506                  30135
# 3              10135                1013506                  30135
# 4              10135                1013506                  30135
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  \
# 0            10136              1013603                30136
# 1            10140              1014005                30140
# 2            10140              1014005                30140
# 3            10140              1014005                30140
# 4            10140              1014005                30140
#
#   REPORTING_CARRIER TICKET_CARRIER OPERATING_CARRIER  BULK_FARE  PASSENGERS  \
# 0                OH             AA                99        0.0         1.0
# 1                9E             DL                99        0.0         1.0
# 2                9E             DL                99        0.0         1.0
# 3                9E             DL                99        0.0         1.0
# 4                9E             DL                99        0.0         1.0
#
#    MARKET_FARE  MARKET_DISTANCE  DISTANCE_GROUP  MARKET_MILES_FLOWN  \
# 0       895.41           1575.0             4.0              1575.0
# 1       168.50           1961.0             4.0              1961.0
# 2       201.84           1961.0             4.0              1961.0
# 3       361.50           1961.0             4.0              1961.0
# 4       843.00           1961.0             4.0              1961.0
#
#    NONSTOP_MILES  MKT_GEO_TYPE
# 0         1458.0           2.0
# 1         1738.0           2.0
# 2         1738.0           2.0
# 3         1738.0           2.0
# 4         1738.0           2.0

# %%
# Data Structure
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30954956 entries, 0 to 30954955
# Data columns (total 19 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   YEAR               int64
#  1   QUARTER            int64
#  2   ORIGIN_AIRPORT_ID  int64
#  3   ORIGIN             object
#  4   DEST_AIRPORT_ID    int64
#  5   DEST               object
#  6   REPORTING_CARRIER  object
#  7   TICKET_CARRIER     object
#  8   OPERATING_CARRIER  object
#  9   BULK_FARE          float64
#  10  PASSENGERS         float64
#  11  MARKET_FARE        float64
#  12  MARKET_DISTANCE    float64
#  13  NONSTOP_MILES      float64
#  14  MKT_GEO_TYPE       int64
#  15  ORIGIN_LAT         float64
#  16  ORIGIN_LON         float64
#  17  DEST_LAT           float64
#  18  DEST_LON           float64
# dtypes: float64(9), int64(5), object(5)
# memory usage: 4.4+ GB
#                YEAR       QUARTER  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  \
# count  3.095496e+07  3.095496e+07       3.095496e+07     3.095496e+07
# mean   2.024483e+03  2.556010e+00       1.282646e+04     1.282576e+04
# std    4.996968e-01  1.103849e+00       1.538928e+03     1.539376e+03
# min    2.024000e+03  1.000000e+00       1.013500e+04     1.013500e+04
# 25%    2.024000e+03  2.000000e+00       1.129800e+04     1.129800e+04
# 50%    2.024000e+03  3.000000e+00       1.291500e+04     1.291500e+04
# 75%    2.025000e+03  4.000000e+00       1.410700e+04     1.410700e+04
# max    2.025000e+03  4.000000e+00       1.642200e+04     1.642200e+04
#
#         BULK_FARE    PASSENGERS   MARKET_FARE  MARKET_DISTANCE  NONSTOP_MILES  \
# count  30954956.0  3.095496e+07  3.095496e+07     3.095496e+07   3.095496e+07
# mean          0.0  1.800781e+00  2.844389e+02     1.294016e+03   1.216880e+03
# std           0.0  3.412425e+00  2.186487e+02     8.139288e+02   7.717897e+02
# min           0.0  1.000000e+00  1.901000e+01     1.100000e+01   1.100000e+01
# 25%           0.0  1.000000e+00  1.615000e+02     7.010000e+02   6.510000e+02
# 50%           0.0  1.000000e+00  2.390000e+02     1.080000e+03   1.015000e+03
# 75%           0.0  1.000000e+00  3.475000e+02     1.744000e+03   1.634000e+03
# max           0.0  4.930000e+02  4.443200e+04     1.134400e+04   9.362000e+03
#
#        MKT_GEO_TYPE    ORIGIN_LAT    ORIGIN_LON      DEST_LAT      DEST_LON
# count  3.095496e+07  3.095496e+07  3.095496e+07  3.095496e+07  3.095496e+07
# mean   1.932556e+00  3.646966e+01 -9.507017e+01  3.649238e+01 -9.503730e+01
# std    2.507886e-01  6.342289e+00  1.921055e+01  6.328931e+00  1.917843e+01
# min    1.000000e+00 -1.433100e+01 -1.766460e+02 -1.433100e+01 -1.766460e+02
# 25%    2.000000e+00  3.289680e+01 -1.119780e+02  3.289680e+01 -1.119780e+02
# 50%    2.000000e+00  3.724570e+01 -8.812960e+01  3.732550e+01 -8.790480e+01
# 75%    2.000000e+00  4.077720e+01 -8.064530e+01  4.077720e+01 -8.029060e+01
# max    2.000000e+00  7.128540e+01  1.457290e+02  7.128540e+01  1.457290e+02

# %% [markdown]
# realized a lot of US airports have missing info
